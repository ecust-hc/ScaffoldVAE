# %%
from rdkit.Chem import Draw
from rdkit import Chem

# %%
mol = ["O=C(CNC(=O)c1ccco1)OCC(=O)c1ccc2ccccc2c1","c1ccc2ccccc2c1"]
Draw.MolsToGridImage([Chem.MolFromSmiles(x) for x in mol])

# %%
mol = ["O=C(COC(=O)CNC(=O)c1ccco1)c1ccc2c(c1)CCC2","O=C(CNC(=O)c1ccco1)OCC(=O)c1cccc2ccccc12","O=C(CNC(=O)c1ccco1)OCC(=O)c1ccc2[nH]c(=S)oc2c1","O=C(CNC(=O)c1ccco1)OCC(=O)c1cccc(-c2cscn2)c1","O=C(CNC(=O)COC(=O)c1cccc2ccccc12)c1cccs1","O=C(CNC(=O)c1occc1-c1ccc2ccccc2c1)OCC(=O)c1ccccc1","O=C1CCc2ccc(NC(=O)COC(=O)CNc3cccc[nH+]3)cc2C1=O"]
Draw.MolsToGridImage([Chem.MolFromSmiles(x) for x in mol])
